# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#Checking the Data
#Checking for NaN values
#Removing NaN Values
#df.dropna(inplace = True)
#Creating the text variable

# %%
df='C:\\Users\\kurre\\OneDrive\\Desktop\\DATA SCIENCE DOCS\\datasets\\android-games.csv'

# %%
df1=pd.read_csv(df)

# %%
df1
# Out:
#       rank                                         title  total ratings  \
# 0        1                Garena Free Fire- World Series       86273129
# 1        2                        PUBG MOBILE - Traverse       37276732
# 2        3                     Mobile Legends: Bang Bang       26663595
# 3        4                                   Brawl Stars       17971552
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...    ...                                           ...            ...
# 1725    96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726    97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727    98                  Scrabble® GO - New Word Game         110723
# 1728    99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729   100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
df1.isna().sum()
# Out:
# rank                0
# title               0
# total ratings       0
# installs            0
# average rating      0
# growth (30 days)    0
# growth (60 days)    0
# price               0
# category            0
# 5 star ratings      0
# 4 star ratings      0
# 3 star ratings      0
# 2 star ratings      0
# 1 star ratings      0
# paid                0
# dtype: int64

# %%
df1.head()
# Out:
#    rank                                         title  total ratings installs  \
# 0     1                Garena Free Fire- World Series       86273129  500.0 M
# 1     2                        PUBG MOBILE - Traverse       37276732  500.0 M
# 2     3                     Mobile Legends: Bang Bang       26663595  100.0 M
# 3     4                                   Brawl Stars       17971552  100.0 M
# 4     5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235  500.0 M
#
#    average rating  growth (30 days)  growth (60 days)  price     category  \
# 0               4               2.1               6.9    0.0  GAME ACTION
# 1               4               1.8               3.6    0.0  GAME ACTION
# 2               4               1.5               3.2    0.0  GAME ACTION
# 3               4               1.4               4.4    0.0  GAME ACTION
# 4               4               0.8               1.5    0.0  GAME ACTION
#
# ...

# %% [markdown]
# - WordCloud is one of method to show most repated words in pictorial form
#
# - Most repeated word displayed as More in Zoom
#
# - Less repeated word displayed as zoom out
#
# - You need to select a column
#
# - Column has different rows
#
# - You need combine all the rows

# %%
for cat in df1.category:
    print(cat.split(' ')[1])
# Out:
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ACTION
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ADVENTURE
# ...

# %%
text=" ".join(cat.split()[1] for cat in df1.category)
text
# Out:
# 'ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTU
# ...

# %%
text=" ".join(cat.split()[1] for cat in df1.category)
from wordcloud import WordCloud
word_cloud = WordCloud(height=2000, width=2000, background_color='black')
word_cloud = word_cloud.generate(text)
plt.imshow(word_cloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, background_color='white')
wordcloud = wordcloud.generate(" ".join(cat.split()[1] for cat in df1.category))
plt.imshow(wordcloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image

# %%
img=Image.open('C:\\Users\\kurre\\OneDrive\\Desktop\\419745086_891355982991781_5447836989563835680_n.jpg')

# %%
img.size
# Out:
# (1080, 1350)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350>

# %%
bbb=np.array(img)
bbb

# 0 to 255
# 0 black
# 255 white
# Out:
# array([[[255, 250, 232],
#         [254, 247, 229],
#         [251, 244, 226],
#         ...,
#         [206, 185, 168],
#         [223, 202, 185],
#         [220, 199, 182]],
#
#        [[254, 247, 229],
#         [254, 247, 229],
#         [254, 247, 229],
#         ...,
#         [206, 185, 168],
#         [214, 193, 176],
#         [202, 181, 164]],
#
#        [[255, 249, 231],
#         [255, 248, 230],
#         [254, 247, 229],
#         ...,
#         [205, 184, 167],
#         [211, 190, 173],
#         [208, 187, 170]],
#
#        ...,
#
#        [[160, 145, 116],
#         [167, 152, 123],
#         [163, 148, 119],
#         ...,
#         [176, 160, 134],
#         [174, 158, 132],
#         [169, 153, 127]],
#
#        [[159, 144, 115],
#         [165, 150, 121],
#         [162, 147, 118],
#         ...,
#         [154, 138, 112],
#         [158, 142, 116],
#         [164, 148, 122]],
#
#        [[160, 145, 116],
#         [165, 150, 121],
#         [160, 145, 116],
# ...

# %%
text=" ".join(cat.split()[1] for cat in df1.category)
from wordcloud import WordCloud
word_cloud = WordCloud(height=2000, 
                       width=2000, 
                       background_color='white',
                       mask=bbb)
word_cloud = word_cloud.generate(text)
plt.imshow(word_cloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
v1=np.array(Image.open('C:\\Users\\kurre\\OneDrive\\Desktop\\419745086_891355982991781_5447836989563835680_n.jpg'))
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, background_color='white',mask=v1)
wordcloud = wordcloud.generate(" ".join(cat.split()[1] for cat in df1.category))
plt.imshow(wordcloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()
